# %% [markdown]
# ### Video Game Sales (VGSales) Dataset

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('vgsales.csv')
df.head(5)
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %% [markdown]
# ### The analysis
# 1. What is the case? Video game sales
# 2. Identification variables? The variables in the data above are name, platform, year, genre, publisher, Na_Sales, EU_Sales, JP_Sales, Other_Sales, Global_Sales
# 3. Classify each variable as categorical or quantitative? Categorical variables are name, platform, genre, and publisher. While the quantitative variables are rank, year, Na_Sales, EU_Sales, JP_Sales, Other_Sales, Global_Sales
# 4. Use labels and explain how you chose them? The label I use is rank, rank is different from the others, with rank you will find out more quickly the highest video game sales.
# 5. Summarize the main characteristics of your data set! This data set is very complete, and makes it easy to find out the sales of the video game. It has been arranged from rank 1 to last, we know the data such as what year the video game was released and its title and there is still a lot of data that is known above. From this data collection, we know that the video game sales that are in high demand are Wii Sports.

# %% [markdown]
# Here I choose NA_Sales for quantitative variable distribution and Platform for categorical variable distribution.

# %%
import matplotlib.pyplot as plt
plt.hist(df['NA_Sales'])
plt.show()

# %% [markdown]
# From the graph above, it can be analyzed that NA_Sales has different values, and the line is vertical, a straight line upwards. This number influences the data for rank, while for the distribution of categorical variables I chose platform to find out the various platforms consisting of several platforms and the diagram is random. With a platform diagram, you can find out which platforms are the most popular in selling this video game.

# %% [markdown]
# Create a scatterplot with 1 quantitative variable and 1 categorical variable

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('vgsales.csv')
df.head(5)
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
df.dtypes
# Out:
# Rank              int64
# Name             object
# Platform         object
# Year            float64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %%
df.shape
# Out:
# (16598, 11)

# %%
print(df.isnull().sum())
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
plt.scatter(df.index,df['NA_Sales'])
plt.show()

# %%
plt.scatter(df.index,df['Platform'])
plt.show()

# %% [markdown]
# If you look at the scatter plot above, the NA_Sales distribution has a higher level at the beginning of the distribution, then decreases drastically and is just flat. Meanwhile, the platform has points that are evenly distributed and stable.

# %% [markdown]
# Next, in this regression I use 2 quantitative variable data, namely EU_Sales and Other_Sales

# %%
import matplotlib.pyplot as plt
from scipy import stats

# %%
x = [29.02, 3.58, 12.88, 11.01, 8.89]
y = [8.46, 0.77, 3.31, 2.96, 1.00]

# %%
slope, intercept, r, p, std_err = stats.linregress(x, y)

# %%
print ('slope=(0), intercept=(1), r=(2), p=(3), std_err=(4) '.format(slope, intercept, r,p,std_err))
# Out:
# slope=(0), intercept=(1), r=(2), p=(3), std_err=(4)

# %%
def myfunc(x) :
    return slope * x + intercept

# %%
mymodel = list(map(myfunc, x))

# %%
plt.scatter(x,y)
plt.plot(x, mymodel)

# %% [markdown]
# From the picture above, this regression definitely has a positive distribution, and has a vertical line sloping upwards. The slope of the regression line cannot change. The new point does not change the correlation, and this, in turn, means the regression line does not change either. The new point on the existing line exactly matches the prediction thus, there is no remainder. Because the regression line produces the least residual sum of squares, adding points with zero residuals does not change the line. Placing a new point on an existing line does not change the average x and y. Thus, the parameters of the regression line remain the same.

# %% [markdown]
# Next I will see which genres are dominant in game sales.

# %%
sns.FacetGrid(df, hue="Genre", size=5) .map(plt.scatter, "EU_Sales", "Global_Sales") .add_legend()
# Out:
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# From the plot above it can be seen that Sport is the genre that produces the most games and has quite high game sales too. Meanwhile, game sales from Strategy are quite low.

# %%
# total number of genres
df.Genre.value_counts()
# Out:
# Action          3316
# Sports          2346
# Misc            1739
# Role-Playing    1488
# Shooter         1310
# Adventure       1286
# Racing          1249
# Platform         886
# Simulation       867
# Fighting         848
# Strategy         681
# Puzzle           582
# Name: Genre, dtype: int64

# %%
# total number of publishers
df.Publisher.value_counts()
# Out:
# Electronic Arts                 1351
# Activision                       975
# Namco Bandai Games               932
# Ubisoft                          921
# Konami Digital Entertainment     832
#                                 ...
# Warp                               1
# New                                1
# Elite                              1
# Evolution Games                    1
# UIG Entertainment                  1
# Name: Publisher, Length: 578, dtype: int64

# %%
# total number of platforms
df.Platform.value_counts()
# Out:
# DS      2163
# PS2     2161
# PS3     1329
# Wii     1325
# X360    1265
# PSP     1213
# PS      1196
# PC       960
# XB       824
# GBA      822
# GC       556
# 3DS      509
# PSV      413
# PS4      336
# N64      319
# SNES     239
# XOne     213
# SAT      173
# WiiU     143
# 2600     133
# NES       98
# GB        98
# DC        52
# GEN       27
# NG        12
# SCD        6
# WS         6
# 3DO        3
# TG16       2
# GG         1
# PCFX       1
# Name: Platform, dtype: int64

# %%
sns.pairplot(df.drop("Genre", axis=1), hue="Platform", size=3)
# Out:
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# The plot above shows the correlation between variables contained in the data. If the variables are compared one by one, the data has a fairly diverse distribution so that the resulting plot is widely spread.
